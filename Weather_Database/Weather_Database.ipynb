# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests

# Import the API key.
from config import weather_api_key as key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | santa cruz
# Processing Record 2 of Set 1 | gradignan
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | vestmannaeyjar
# Processing Record 7 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | kautokeino
# Processing Record 11 of Set 1 | senador pompeu
# Processing Record 12 of Set 1 | majene
# Processing Record 13 of Set 1 | yurimaguas
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | qasigiannguit
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | nikologory
# Processing Record 25 of Set 1 | liwale
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | hualmay
# Processing Record 28 of Set 1 | qaqortoq
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | goderich
# Processing Record 34 of Set 1 | lata
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 1 | port hardy
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | puerto del rosario
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | roebourne
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | rafaela
# Processing Record 3 of Set 2 | kaitangata
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | fortuna
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 2 | kualakapuas
# Processing Record 11 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | cabo san lucas
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | nieves
# Processing Record 19 of Set 2 | lanigan
# Processing Record 20 of Set 2 | penzance
# Processing Record 21 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 22 of Set 2 | kedrovyy
# Processing Record 23 of Set 2 | kulhudhuffushi
# Processing Record 24 of Set 2 | kahului
# Processing Record 25 of Set 2 | walvis bay
# Processing Record 26 of Set 2 | witu
# Processing Record 27 of Set 2 | huarmey
# Processing Record 28 of Set 2 | vestmanna
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | trelew
# Processing Record 31 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 2 | emerald
# Processing Record 33 of Set 2 | lodja
# Processing Record 34 of Set 2 | nouadhibou
# Processing Record 35 of Set 2 | dhone
# Processing Record 36 of Set 2 | cape town
# Processing Record 37 of Set 2 | port macquarie
# Processing Record 38 of Set 2 | lumphat
# Processing Record 39 of Set 2 | peniche
# Processing Record 40 of Set 2 | sorland
# Processing Record 41 of Set 2 | zhezkazgan
# Processing Record 42 of Set 2 | palana
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | katangli
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | dauphin
# Processing Record 49 of Set 2 | pevek
# Processing Record 50 of Set 2 | olafsvik
# Processing Record 1 of Set 3 | angoche
# Processing Record 2 of Set 3 | santa rosa
# Processing Record 3 of Set 3 | ndele
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | clyde river
# Processing Record 6 of Set 3 | kuusamo
# Processing Record 7 of Set 3 | provideniya
# Processing Record 8 of Set 3 | norman wells
# Processing Record 9 of Set 3 | poum
# Processing Record 10 of Set 3 | velsk
# Processing Record 11 of Set 3 | adre
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | imbituba
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | carutapera
# Processing Record 16 of Set 3 | diamantino
# Processing Record 17 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 3 | leczna
# Processing Record 19 of Set 3 | sarakhs
# Processing Record 20 of Set 3 | loyga
# Processing Record 21 of Set 3 | santa maria da vitoria
# Processing Record 22 of Set 3 | culiacan
# Processing Record 23 of Set 3 | bambous virieux
# Processing Record 24 of Set 3 | krasnoselkup
# Processing Record 25 of Set 3 | amapa
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | lagoa
# Processing Record 29 of Set 3 | anadyr
# Processing Record 30 of Set 3 | honiara
# Processing Record 31 of Set 3 | thompson
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | caravelas
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | lesnoy
# Processing Record 36 of Set 3 | xuddur
# Processing Record 37 of Set 3 | amuntai
# Processing Record 38 of Set 3 | jutai
# Processing Record 39 of Set 3 | kenai
# Processing Record 40 of Set 3 | esperance
# Processing Record 41 of Set 3 | weilheim
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | egvekinot
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | baglan
# Processing Record 46 of Set 3 | ketchikan
# Processing Record 47 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 3 | silly
# Processing Record 49 of Set 3 | suba
# Processing Record 50 of Set 3 | lazaro cardenas
# Processing Record 1 of Set 4 | beringovskiy
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | moratuwa
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | phan thiet
# Processing Record 7 of Set 4 | suntar
# Processing Record 8 of Set 4 | rocha
# Processing Record 9 of Set 4 | jardim
# Processing Record 10 of Set 4 | srednekolymsk
# Processing Record 11 of Set 4 | ikot ekpene
# Processing Record 12 of Set 4 | sinnamary
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | sanmenxia
# Processing Record 15 of Set 4 | tuktoyaktuk
# Processing Record 16 of Set 4 | cayenne
# Processing Record 17 of Set 4 | sao gabriel da cachoeira
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | havoysund
# Processing Record 20 of Set 4 | constitucion
# Processing Record 21 of Set 4 | fare
# Processing Record 22 of Set 4 | batemans bay
# Processing Record 23 of Set 4 | mango
# Processing Record 24 of Set 4 | pitimbu
# Processing Record 25 of Set 4 | luderitz
# Processing Record 26 of Set 4 | bima
# Processing Record 27 of Set 4 | port hedland
# Processing Record 28 of Set 4 | campbell river
# Processing Record 29 of Set 4 | pasighat
# Processing Record 30 of Set 4 | yeppoon
# Processing Record 31 of Set 4 | chicama
# Processing Record 32 of Set 4 | bilma
# Processing Record 33 of Set 4 | luanda
# Processing Record 34 of Set 4 | cururupu
# Processing Record 35 of Set 4 | nemuro
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | sabang
# Processing Record 38 of Set 4 | jumla
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | rorvik
# Processing Record 41 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 42 of Set 4 | north myrtle beach
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | ponta delgada
# Processing Record 45 of Set 4 | moanda
# Processing Record 46 of Set 4 | ewa beach
# Processing Record 47 of Set 4 | suzzara
# Processing Record 48 of Set 4 | lamu
# Processing Record 49 of Set 4 | doctor mora
# Processing Record 50 of Set 4 | grand gaube
# Processing Record 1 of Set 5 | muncar
# Processing Record 2 of Set 5 | naze
# Processing Record 3 of Set 5 | hingoli
# Processing Record 4 of Set 5 | bongandanga
# Processing Record 5 of Set 5 | svetlogorsk
# Processing Record 6 of Set 5 | gazojak
# Processing Record 7 of Set 5 | wad madani
# Processing Record 8 of Set 5 | kamaishi
# Processing Record 9 of Set 5 | ahipara
# Processing Record 10 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 5 | ruangwa
# Processing Record 12 of Set 5 | broken hill
# Processing Record 13 of Set 5 | foz
# Processing Record 14 of Set 5 | biltine
# Processing Record 15 of Set 5 | abu zabad
# Processing Record 16 of Set 5 | sarai
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | kemijarvi
# Processing Record 19 of Set 5 | cedar city
# Processing Record 20 of Set 5 | karasjok
# Processing Record 21 of Set 5 | odweyne
# Processing Record 22 of Set 5 | kargasok
# Processing Record 23 of Set 5 | covasint
# Processing Record 24 of Set 5 | porbandar
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | vila velha
# Processing Record 27 of Set 5 | kassala
# Processing Record 28 of Set 5 | pacific grove
# Processing Record 29 of Set 5 | labuhan
# Processing Record 30 of Set 5 | nova soure
# Processing Record 31 of Set 5 | mehriz
# Processing Record 32 of Set 5 | sisimiut
# Processing Record 33 of Set 5 | ust-karsk
# Processing Record 34 of Set 5 | tecoanapa
# Processing Record 35 of Set 5 | karratha
# Processing Record 36 of Set 5 | talnakh
# Processing Record 37 of Set 5 | maues
# Processing Record 38 of Set 5 | eenhana
# Processing Record 39 of Set 5 | ayame
# Processing Record 40 of Set 5 | vila
# Processing Record 41 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 5 | galesong
# Processing Record 43 of Set 5 | ayna
# Processing Record 44 of Set 5 | kuala terengganu
# Processing Record 45 of Set 5 | salalah
# Processing Record 46 of Set 5 | samarai
# Processing Record 47 of Set 5 | maniitsoq
# Processing Record 48 of Set 5 | oktyabrskiy
# Processing Record 49 of Set 5 | nago
# Processing Record 50 of Set 5 | lompoc
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 6 | damghan
# Processing Record 5 of Set 6 | lavrentiya
# Processing Record 6 of Set 6 | new norfolk
# Processing Record 7 of Set 6 | havelock
# Processing Record 8 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 6 | ostrovnoy
# Processing Record 10 of Set 6 | sukumo
# Processing Record 11 of Set 6 | salamiyah
# Processing Record 12 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 13 of Set 6 | tawang
# Processing Record 14 of Set 6 | anloga
# Processing Record 15 of Set 6 | pedan
# City not found. Skipping...
# Processing Record 16 of Set 6 | hamilton
# Processing Record 17 of Set 6 | chanute
# Processing Record 18 of Set 6 | rio gallegos
# Processing Record 19 of Set 6 | meulaboh
# Processing Record 20 of Set 6 | hasaki
# Processing Record 21 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | mount gambier
# Processing Record 25 of Set 6 | funtua
# Processing Record 26 of Set 6 | christchurch
# Processing Record 27 of Set 6 | pangnirtung
# Processing Record 28 of Set 6 | malanje
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | mount isa
# Processing Record 31 of Set 6 | waihi beach
# Processing Record 32 of Set 6 | saldanha
# Processing Record 33 of Set 6 | hobart
# Processing Record 34 of Set 6 | rocky mountain house
# Processing Record 35 of Set 6 | san cristobal
# Processing Record 36 of Set 6 | dauriya
# Processing Record 37 of Set 6 | manokwari
# Processing Record 38 of Set 6 | chokurdakh
# Processing Record 39 of Set 6 | vostochnyy
# Processing Record 40 of Set 6 | college
# Processing Record 41 of Set 6 | manzanillo
# Processing Record 42 of Set 6 | yar-sale
# Processing Record 43 of Set 6 | coquimbo
# Processing Record 44 of Set 6 | asfi
# Processing Record 45 of Set 6 | port blair
# Processing Record 46 of Set 6 | muroto
# Processing Record 47 of Set 6 | aswan
# Processing Record 48 of Set 6 | fuyang
# Processing Record 49 of Set 6 | garowe
# Processing Record 50 of Set 6 | veraval
# Processing Record 1 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 7 | kamenka
# Processing Record 3 of Set 7 | atliaca
# Processing Record 4 of Set 7 | sheboygan
# Processing Record 5 of Set 7 | hudiksvall
# Processing Record 6 of Set 7 | richards bay
# Processing Record 7 of Set 7 | najran
# Processing Record 8 of Set 7 | bogorodskoye
# Processing Record 9 of Set 7 | mednogorsk
# Processing Record 10 of Set 7 | valdivia
# Processing Record 11 of Set 7 | mastic beach
# Processing Record 12 of Set 7 | maumere
# Processing Record 13 of Set 7 | tocopilla
# Processing Record 14 of Set 7 | pokhara
# Processing Record 15 of Set 7 | loukhi
# Processing Record 16 of Set 7 | moindou
# Processing Record 17 of Set 7 | vanimo
# Processing Record 18 of Set 7 | venado tuerto
# Processing Record 19 of Set 7 | hofn
# Processing Record 20 of Set 7 | faya
# Processing Record 21 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 7 | amparai
# City not found. Skipping...
# Processing Record 23 of Set 7 | talara
# Processing Record 24 of Set 7 | biak
# Processing Record 25 of Set 7 | bischofswerda
# Processing Record 26 of Set 7 | abu samrah
# Processing Record 27 of Set 7 | harper
# Processing Record 28 of Set 7 | atambua
# Processing Record 29 of Set 7 | concordia
# Processing Record 30 of Set 7 | leshukonskoye
# Processing Record 31 of Set 7 | atar
# Processing Record 32 of Set 7 | nyagan
# Processing Record 33 of Set 7 | pisco
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 7 | saint anthony
# Processing Record 37 of Set 7 | praia da vitoria
# Processing Record 38 of Set 7 | we
# City not found. Skipping...
# Processing Record 39 of Set 7 | vikhorevka
# Processing Record 40 of Set 7 | verkhnyaya toyma
# Processing Record 41 of Set 7 | mosquera
# Processing Record 42 of Set 7 | los llanos de aridane
# Processing Record 43 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 44 of Set 7 | launceston
# Processing Record 45 of Set 7 | te anau
# Processing Record 46 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 7 | afonso bezerra
# Processing Record 48 of Set 7 | harnai
# Processing Record 49 of Set 7 | ereymentau
# Processing Record 50 of Set 7 | saint-augustin
# Processing Record 1 of Set 8 | kochi
# Processing Record 2 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 3 of Set 8 | whitehorse
# Processing Record 4 of Set 8 | katherine
# Processing Record 5 of Set 8 | sernur
# Processing Record 6 of Set 8 | daura
# Processing Record 7 of Set 8 | aklavik
# Processing Record 8 of Set 8 | faanui
# Processing Record 9 of Set 8 | airai
# Processing Record 10 of Set 8 | namibe
# Processing Record 11 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 8 | ulety
# Processing Record 13 of Set 8 | hambantota
# Processing Record 14 of Set 8 | mayo
# Processing Record 15 of Set 8 | pasaje
# Processing Record 16 of Set 8 | marsh harbour
# Processing Record 17 of Set 8 | conceicao das alagoas
# Processing Record 18 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 8 | methoni
# Processing Record 20 of Set 8 | yichang
# Processing Record 21 of Set 8 | okhotsk
# Processing Record 22 of Set 8 | el wasta
# City not found. Skipping...
# Processing Record 23 of Set 8 | broome
# Processing Record 24 of Set 8 | colares
# Processing Record 25 of Set 8 | awbari
# Processing Record 26 of Set 8 | minot
# Processing Record 27 of Set 8 | bentong
# Processing Record 28 of Set 8 | gat
# Processing Record 29 of Set 8 | dekoa
# City not found. Skipping...
# Processing Record 30 of Set 8 | taoudenni
# Processing Record 31 of Set 8 | gamba
# Processing Record 32 of Set 8 | fillan
# Processing Record 33 of Set 8 | luz
# Processing Record 34 of Set 8 | fukue
# Processing Record 35 of Set 8 | sarangani
# Processing Record 36 of Set 8 | balyaga
# Processing Record 37 of Set 8 | bundaberg
# Processing Record 38 of Set 8 | presidencia roque saenz pena
# Processing Record 39 of Set 8 | belaya gora
# Processing Record 40 of Set 8 | sinop
# Processing Record 41 of Set 8 | klaksvik
# Processing Record 42 of Set 8 | aykhal
# Processing Record 43 of Set 8 | lasa
# Processing Record 44 of Set 8 | yaan
# Processing Record 45 of Set 8 | washington
# Processing Record 46 of Set 8 | ongandjera
# Processing Record 47 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 8 | namatanai
# Processing Record 49 of Set 8 | santa maria
# Processing Record 50 of Set 8 | mizdah
# Processing Record 1 of Set 9 | lauterbach
# Processing Record 2 of Set 9 | nome
# Processing Record 3 of Set 9 | anito
# Processing Record 4 of Set 9 | tefe
# Processing Record 5 of Set 9 | berbera
# Processing Record 6 of Set 9 | alappuzha
# Processing Record 7 of Set 9 | tuatapere
# Processing Record 8 of Set 9 | ponta do sol
# Processing Record 9 of Set 9 | sao felix do xingu
# Processing Record 10 of Set 9 | maragogi
# Processing Record 11 of Set 9 | chimbote
# Processing Record 12 of Set 9 | bubaque
# Processing Record 13 of Set 9 | soe
# Processing Record 14 of Set 9 | afikpo
# Processing Record 15 of Set 9 | east london
# Processing Record 16 of Set 9 | zhanakorgan
# Processing Record 17 of Set 9 | vichayal
# City not found. Skipping...
# Processing Record 18 of Set 9 | hirara
# Processing Record 19 of Set 9 | tura
# Processing Record 20 of Set 9 | catuday
# Processing Record 21 of Set 9 | brae
# Processing Record 22 of Set 9 | san patricio
# Processing Record 23 of Set 9 | surt
# Processing Record 24 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 9 | tarakan
# Processing Record 26 of Set 9 | campana
# Processing Record 27 of Set 9 | pitkyaranta
# Processing Record 28 of Set 9 | dobresti
# Processing Record 29 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 30 of Set 9 | dongsheng
# Processing Record 31 of Set 9 | jawhar
# Processing Record 32 of Set 9 | ilulissat
# Processing Record 33 of Set 9 | svarstad
# Processing Record 34 of Set 9 | oktyabrskoye
# Processing Record 35 of Set 9 | vardo
# Processing Record 36 of Set 9 | ancud
# Processing Record 37 of Set 9 | panama city
# Processing Record 38 of Set 9 | belluru
# Processing Record 39 of Set 9 | mariinsk
# Processing Record 40 of Set 9 | belmonte
# Processing Record 41 of Set 9 | kohtla-nomme
# Processing Record 42 of Set 9 | dunedin
# Processing Record 43 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 9 | padang
# Processing Record 45 of Set 9 | kaohsiung
# Processing Record 46 of Set 9 | alta floresta
# Processing Record 47 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 9 | avera
# Processing Record 49 of Set 9 | siderno
# Processing Record 50 of Set 9 | yulara
# Processing Record 1 of Set 10 | sao sebastiao do paraiso
# Processing Record 2 of Set 10 | mormugao
# Processing Record 3 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 4 of Set 10 | fairbanks
# Processing Record 5 of Set 10 | lubango
# Processing Record 6 of Set 10 | mar del plata
# Processing Record 7 of Set 10 | wilmington
# Processing Record 8 of Set 10 | san juan
# Processing Record 9 of Set 10 | nha trang
# Processing Record 10 of Set 10 | biankouma
# Processing Record 11 of Set 10 | cologne
# Processing Record 12 of Set 10 | cascavel
# Processing Record 13 of Set 10 | bisira
# Processing Record 14 of Set 10 | tomatlan
# Processing Record 15 of Set 10 | floro
# Processing Record 16 of Set 10 | rexburg
# Processing Record 17 of Set 10 | vila franca do campo
# Processing Record 18 of Set 10 | souillac
# Processing Record 19 of Set 10 | maraba
# Processing Record 20 of Set 10 | krasnozerskoye
# Processing Record 21 of Set 10 | tula de allende
# Processing Record 22 of Set 10 | oussouye
# Processing Record 23 of Set 10 | komsomolskiy
# Processing Record 24 of Set 10 | leh
# Processing Record 25 of Set 10 | saint combs
# City not found. Skipping...
# Processing Record 26 of Set 10 | asau
# Processing Record 27 of Set 10 | milton
# Processing Record 28 of Set 10 | orcopampa
# Processing Record 29 of Set 10 | palmer
# Processing Record 30 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 10 | itatskiy
# Processing Record 32 of Set 10 | huangzhai
# Processing Record 33 of Set 10 | nagato
# Processing Record 34 of Set 10 | breves
# Processing Record 35 of Set 10 | vao
# Processing Record 36 of Set 10 | oschersleben
# Processing Record 37 of Set 10 | boa vista
# Processing Record 38 of Set 10 | emba
# Processing Record 39 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 10 | odoyev
# Processing Record 41 of Set 10 | linguere
# Processing Record 42 of Set 10 | iskateley
# Processing Record 43 of Set 10 | kyenjojo
# Processing Record 44 of Set 10 | tete
# Processing Record 45 of Set 10 | satwas
# Processing Record 46 of Set 10 | iranshahr
# Processing Record 47 of Set 10 | kholodnyy
# Processing Record 48 of Set 10 | richard toll
# City not found. Skipping...
# Processing Record 49 of Set 10 | kesennuma
# City not found. Skipping...
# Processing Record 50 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 11 | port-gentil
# Processing Record 2 of Set 11 | bielsko-biala
# Processing Record 3 of Set 11 | bayan
# Processing Record 4 of Set 11 | sorong
# Processing Record 5 of Set 11 | nelson bay
# Processing Record 6 of Set 11 | bolobo
# Processing Record 7 of Set 11 | vicente guerrero
# Processing Record 8 of Set 11 | roald
# Processing Record 9 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 11 | abapo
# Processing Record 11 of Set 11 | bichura
# Processing Record 12 of Set 11 | pakxan
# Processing Record 13 of Set 11 | pangody
# Processing Record 14 of Set 11 | springbok
# Processing Record 15 of Set 11 | batagay-alyta
# Processing Record 16 of Set 11 | vire
# Processing Record 17 of Set 11 | jalu
# Processing Record 18 of Set 11 | alofi
# Processing Record 19 of Set 11 | piacabucu
# Processing Record 20 of Set 11 | inverness
# Processing Record 21 of Set 11 | udachnyy
# Processing Record 22 of Set 11 | alexandria
# Processing Record 23 of Set 11 | olavarria
# Processing Record 24 of Set 11 | thohoyandou
# Processing Record 25 of Set 11 | pudozh
# Processing Record 26 of Set 11 | mananjary
# Processing Record 27 of Set 11 | rokupr
# Processing Record 28 of Set 11 | umm lajj
# Processing Record 29 of Set 11 | burns lake
# Processing Record 30 of Set 11 | tupik
# Processing Record 31 of Set 11 | whyalla
# Processing Record 32 of Set 11 | the pas
# Processing Record 33 of Set 11 | aranda de duero
# Processing Record 34 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 11 | tiruchchendur
# Processing Record 36 of Set 11 | saint george
# Processing Record 37 of Set 11 | saint-francois
# Processing Record 38 of Set 11 | pinawa
# Processing Record 39 of Set 11 | sao jose do campestre
# Processing Record 40 of Set 11 | lethem
# Processing Record 41 of Set 11 | ilhabela
# Processing Record 42 of Set 11 | gonen
# Processing Record 43 of Set 11 | katsuura
# Processing Record 44 of Set 11 | tabas
# Processing Record 45 of Set 11 | rawson
# Processing Record 46 of Set 11 | bonfim
# Processing Record 47 of Set 11 | goteborg
# City not found. Skipping...
# Processing Record 48 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 11 | gallup
# Processing Record 50 of Set 11 | manggar
# Processing Record 1 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 12 | inuvik
# Processing Record 3 of Set 12 | mugur-aksy
# Processing Record 4 of Set 12 | dingle
# Processing Record 5 of Set 12 | noyabrsk
# Processing Record 6 of Set 12 | likasi
# Processing Record 7 of Set 12 | mantua
# Processing Record 8 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 12 | wasaga beach
# Processing Record 10 of Set 12 | filingue
# Processing Record 11 of Set 12 | kuruman
# Processing Record 12 of Set 12 | killarney
# Processing Record 13 of Set 12 | thaton
# Processing Record 14 of Set 12 | erzin
# Processing Record 15 of Set 12 | kharp
# Processing Record 16 of Set 12 | ajdabiya
# Processing Record 17 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 12 | shache
# Processing Record 19 of Set 12 | ouadda
# Processing Record 20 of Set 12 | taldan
# Processing Record 21 of Set 12 | enshi
# Processing Record 22 of Set 12 | gomel
# Processing Record 23 of Set 12 | guiglo
# Processing Record 24 of Set 12 | misratah
# Processing Record 25 of Set 12 | sabha
# Processing Record 26 of Set 12 | langsa
# Processing Record 27 of Set 12 | lumajang
# Processing Record 28 of Set 12 | vung tau
# Processing Record 29 of Set 12 | brighton
# Processing Record 30 of Set 12 | zyryanskoye
# Processing Record 31 of Set 12 | aberdeen
# Processing Record 32 of Set 12 | canmore
# Processing Record 33 of Set 12 | hue
# Processing Record 34 of Set 12 | arklow
# Processing Record 35 of Set 12 | antalaha
# Processing Record 36 of Set 12 | yerbogachen
# Processing Record 37 of Set 12 | takoradi
# Processing Record 38 of Set 12 | bedesa
# Processing Record 39 of Set 12 | natal
# Processing Record 40 of Set 12 | mana
# Processing Record 41 of Set 12 | codrington
# Processing Record 42 of Set 12 | kenora
# Processing Record 43 of Set 12 | puerto escondido
# Processing Record 44 of Set 12 | kyra
# Processing Record 45 of Set 12 | skibbereen
# Processing Record 46 of Set 12 | kraslava
# Processing Record 47 of Set 12 | zharkent
# Processing Record 48 of Set 12 | iracoubo
# Processing Record 49 of Set 12 | northam
# Processing Record 50 of Set 12 | shingu
# Processing Record 1 of Set 13 | dabat
# Processing Record 2 of Set 13 | atherton
# Processing Record 3 of Set 13 | mogadishu
# Processing Record 4 of Set 13 | chapais
# Processing Record 5 of Set 13 | lincoln
# Processing Record 6 of Set 13 | verkhnevilyuysk
# Processing Record 7 of Set 13 | oga
# Processing Record 8 of Set 13 | kavaratti
# Processing Record 9 of Set 13 | erenhot
# Processing Record 10 of Set 13 | dekalb
# Processing Record 11 of Set 13 | nuevitas
# Processing Record 12 of Set 13 | mancio lima
# Processing Record 13 of Set 13 | reichenau
# Processing Record 14 of Set 13 | cabedelo
# Processing Record 15 of Set 13 | kodinsk
# Processing Record 16 of Set 13 | mnogovershinnyy
# Processing Record 17 of Set 13 | mackay
# Processing Record 18 of Set 13 | maryborough
# Processing Record 19 of Set 13 | nisia floresta
# Processing Record 20 of Set 13 | soverato
# Processing Record 21 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 13 | gigmoto
# Processing Record 23 of Set 13 | waingapu
# Processing Record 24 of Set 13 | tchollire
# Processing Record 25 of Set 13 | westport
# Processing Record 26 of Set 13 | puri
# Processing Record 27 of Set 13 | buala
# Processing Record 28 of Set 13 | necochea
# Processing Record 29 of Set 13 | temirtau
# Processing Record 30 of Set 13 | san miguel
# Processing Record 31 of Set 13 | ryotsu
# Processing Record 32 of Set 13 | veracruz
# Processing Record 33 of Set 13 | irituia
# Processing Record 34 of Set 13 | filadelfia
# Processing Record 35 of Set 13 | ciudad bolivar
# Processing Record 36 of Set 13 | nizhniy kuranakh
# Processing Record 37 of Set 13 | menongue
# Processing Record 38 of Set 13 | conde
# Processing Record 39 of Set 13 | yumen
# Processing Record 40 of Set 13 | caceres
# Processing Record 41 of Set 13 | saiha
# Processing Record 42 of Set 13 | lafiagi
# Processing Record 43 of Set 13 | eskil
# Processing Record 44 of Set 13 | wajir
# Processing Record 45 of Set 13 | impfondo
# Processing Record 46 of Set 13 | matamba
# Processing Record 47 of Set 13 | meridian
# Processing Record 48 of Set 13 | vagur
# Processing Record 49 of Set 13 | araguaina
# Processing Record 50 of Set 13 | suileng
# Processing Record 1 of Set 14 | hoquiam
# Processing Record 2 of Set 14 | urumqi
# Processing Record 3 of Set 14 | bud
# Processing Record 4 of Set 14 | taltal
# Processing Record 5 of Set 14 | kandrian
# Processing Record 6 of Set 14 | valley city
# Processing Record 7 of Set 14 | mill valley
# Processing Record 8 of Set 14 | belgrade
# Processing Record 9 of Set 14 | wolmirstedt
# Processing Record 10 of Set 14 | salinopolis
# Processing Record 11 of Set 14 | kropotkin
# Processing Record 12 of Set 14 | dumabato
# Processing Record 13 of Set 14 | san andres
# Processing Record 14 of Set 14 | balabac
# Processing Record 15 of Set 14 | severnyy
# Processing Record 16 of Set 14 | raudeberg
# Processing Record 17 of Set 14 | salisbury
# Processing Record 18 of Set 14 | bay roberts
# Processing Record 19 of Set 14 | altamira
# Processing Record 20 of Set 14 | taos
# Processing Record 21 of Set 14 | ambatofinandrahana
# Processing Record 22 of Set 14 | bognor regis
# Processing Record 23 of Set 14 | galle
# Processing Record 24 of Set 14 | touros
# Processing Record 25 of Set 14 | palma di montechiaro
# Processing Record 26 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 14 | blagoyevo
# Processing Record 28 of Set 14 | trairi
# Processing Record 29 of Set 14 | petukhovo
# Processing Record 30 of Set 14 | sechura
# Processing Record 31 of Set 14 | shaunavon
# Processing Record 32 of Set 14 | arlit
# Processing Record 33 of Set 14 | yurkivka
# Processing Record 34 of Set 14 | grants pass
# Processing Record 35 of Set 14 | payo
# Processing Record 36 of Set 14 | natagaima
# Processing Record 37 of Set 14 | nuuk
# Processing Record 38 of Set 14 | pedernales
# Processing Record 39 of Set 14 | nur
# Processing Record 40 of Set 14 | chumikan
# Processing Record 41 of Set 14 | ejea de los caballeros
# Processing Record 42 of Set 14 | el alto
# Processing Record 43 of Set 14 | acuna
# City not found. Skipping...
# Processing Record 44 of Set 14 | aranos
# Processing Record 45 of Set 14 | riviere-au-renard
# Processing Record 46 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 14 | acapulco
# Processing Record 48 of Set 14 | mitsamiouli
# Processing Record 49 of Set 14 | lingyuan
# Processing Record 50 of Set 14 | vuktyl
# Processing Record 1 of Set 15 | riyadh
# Processing Record 2 of Set 15 | villa maria
# Processing Record 3 of Set 15 | camarillo
# Processing Record 4 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 15 | bandundu
# Processing Record 6 of Set 15 | doha
# Processing Record 7 of Set 15 | morrope
# Processing Record 8 of Set 15 | denpasar
# Processing Record 9 of Set 15 | mangai
# Processing Record 10 of Set 15 | chama
# Processing Record 11 of Set 15 | nichinan
# Processing Record 12 of Set 15 | harindanga
# Processing Record 13 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 14 of Set 15 | falkoping
# City not found. Skipping...
# Processing Record 15 of Set 15 | roswell
# Processing Record 16 of Set 15 | coahuayana
# Processing Record 17 of Set 15 | farah
# Processing Record 18 of Set 15 | baltasi
# Processing Record 19 of Set 15 | coruripe
# Processing Record 20 of Set 15 | coolum beach
# Processing Record 21 of Set 15 | aasiaat
# Processing Record 22 of Set 15 | berdigestyakh
# Processing Record 23 of Set 15 | hays
# Processing Record 24 of Set 15 | yangambi
# Processing Record 25 of Set 15 | cardston
# Processing Record 26 of Set 15 | nawada
# Processing Record 27 of Set 15 | takaka
# Processing Record 28 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 15 | zhigansk
# Processing Record 30 of Set 15 | khandbari
# Processing Record 31 of Set 15 | nanakuli
# Processing Record 32 of Set 15 | dudinka
# Processing Record 33 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 15 | tevaitoa
# Processing Record 35 of Set 15 | isperih
# Processing Record 36 of Set 15 | bhiwani
# Processing Record 37 of Set 15 | ouesso
# Processing Record 38 of Set 15 | hami
# Processing Record 39 of Set 15 | shimoda
# Processing Record 40 of Set 15 | shinpokh
# Processing Record 41 of Set 15 | roi et
# Processing Record 42 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 15 | tambul
# City not found. Skipping...
# Processing Record 44 of Set 15 | jaslo
# Processing Record 45 of Set 15 | san ramon
# Processing Record 46 of Set 15 | tulum
# Processing Record 47 of Set 15 | islamkot
# Processing Record 48 of Set 15 | bukama
# Processing Record 49 of Set 15 | mpanda
# Processing Record 50 of Set 15 | pierre
# Processing Record 1 of Set 16 | mattru
# Processing Record 2 of Set 16 | santa marta
# Processing Record 3 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 16 | dakar
# Processing Record 5 of Set 16 | khamanon
# Processing Record 6 of Set 16 | horconcitos
# Processing Record 7 of Set 16 | mandalgovi
# Processing Record 8 of Set 16 | nishihara
# Processing Record 9 of Set 16 | muhos
# Processing Record 10 of Set 16 | korla
# Processing Record 11 of Set 16 | carroll
# Processing Record 12 of Set 16 | madaoua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 696

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Santa Cruz      BO -17.8000  -63.1667     78.26        78          75
# 1       Gradignan      FR  44.7726   -0.6139     48.18        90          75
# 2      Bredasdorp      ZA -34.5322   20.0403     59.29        94         100
# 3          Albany      US  42.6001  -73.9662     38.80        59         100
# 4           Bluff      NZ -46.6000  168.3333     55.80        54          13
# 5  Vestmannaeyjar      IS  63.4427  -20.2734     43.47        69          62
# 6         Mataura      NZ -46.1927  168.8643     55.47        44          87
# 7      Kautokeino      NO  69.0125   23.0412    -24.54       100          98
# 8  Senador Pompeu      BR  -5.5881  -39.3717     82.04        65          23
# 9          Majene      ID  -3.5403  118.9707     80.91        82         100
#
#    Wind Speed Current Description
# 0        6.91       broken clouds
# 1        1.01       broken clouds
# 2       10.00       moderate rain
# 3        6.13     overcast clouds
# 4       19.22          few clouds
# 5       22.97       broken clouds
# 6        7.25     overcast clouds
# 7        4.38     overcast clouds
# 8        9.13          few clouds
# 9        8.39     very heavy rain

# %%
#Create the output file CSV
output_file="WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_file, index_label="City_ID")
